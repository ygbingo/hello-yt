# %%
import pandas as pd
df=pd.read_excel("./商品属性表1 0707 lite.xlsx",sheet_name="阿玛尼")
df
# Out:
#                      产品名称                                       介绍     规格  \
# 0                 阿玛尼挚爱唇膏                                浓郁出色 丝滑润泽     4g
# 1             阿玛尼臻致丝绒哑光唇釉                                丝绒哑光 浓郁色彩  6.5ml
# 2               阿玛尼漆光迷情唇釉                                极致闪耀 迷情漆光  6.5ml
# 3            阿玛尼持色凝彩哑光染唇液                                水感哑光 轻薄持久  6.5ml
# 4               阿玛尼莹润迷情唇膏                                水漾闪耀 柔润滋养     3g
# ..                    ...                                      ...    ...
# 144           阿玛尼权力唇膏-108                                持久滋润 成膜口红     3g
# 145           阿玛尼权利唇膏-202                  首支会成膜的唇膏 超长锁色锁锁水 披上护唇战衣     3g
# 146               阿玛尼权利唇膏                          独特持色UP科技 革新权利战衣     3g
# 147  阿玛尼高定私藏香氛(环游系列)靛蓝坦桑石   香柠檬与杏仁的温柔碰撞,奶香与天芥花香的明媚交织,醇厚树脂与安息香的沉稳追逐  100ml
# 148  阿玛尼高定私藏香氛(环游系列)洋红坦桑石  小豆蔻,肉桂的辛香碰撞,咖啡,纳米比亚没药的暖意交织,烟草与波旁香草的性感追逐  100ml
#
#         价格  Unnamed: 4                                                 图片  \
# 0     ￥310      4g￥310  https://chat-bot.lorealchina.com/gacSource/bac...
# 1     ￥310   6.5ml￥310  https://chat-bot.lorealchina.com/gacSource/bac...
# 2     ￥310   6.5ml￥310  https://chat-bot.lorealchina.com/gacSource/bac...
# 3     ￥340   6.5ml￥340  https://chat-bot.lorealchina.com/gacSource/bac...
# 4     ￥320      3g￥320  https://chat-bot.lorealchina.com/gacSource/bac...
# ..     ...         ...                                                ...
# 144   ￥350      3g￥350  https://chat-bot.lorealchina.com/gacSource/bac...
# 145   ￥350      3g￥350  https://chat-bot.lorealchina.com/gacSource/bac...
# 146   ￥350      3g￥350  https://chat-bot.lorealchina.com/gacSource/bac...
# 147  ￥2500  100ml￥2500  https://chat-bot.lorealchina.com/gacSource/bac...
# 148  ￥2500  100ml￥2500  https://chat-bot.lorealchina.com/gacSource/bac...
#
#                            功能 适用肤质
# 0                  哑而不干，持久不脱色  NaN
# 1       色泽浓郁饱满，丝绒哑光妆效，8小时润泽舒适  NaN
# 2        色彩浓郁，轻盈滋润，快速成膜，持久不脱色  NaN
# 3    高饱和哑光色彩，至轻至薄，宛若无物，8小时不脱色  NaN
# 4     唇蜜般水漾闪耀，润唇膏般柔润滋养，色彩饱满浓郁  NaN
# ..                        ...  ...
# 144                       NaN  NaN
# 145      高级棕红 秋冬必选 时髦气质 出场即控场  NaN
# 146                       NaN  NaN
# 147                东方木质调,温郁内敛  NaN
# 148                东方辛香调,自由野性  NaN
#
# [149 rows x 8 columns]

# %%
for idx, _ in df.iterrows():
    if not isinstance(df.iloc[idx,6], str):
        continue
    df.iloc[idx,6] = df.iloc[idx,6].replace(" ","，")
df.to_excel("./amani_label.xlsx",sheet_name="amani",index=False)

# %%
df2=pd.read_excel("./amani_label.xlsx")
a=list(df2.loc[0:147,'Unnamed: 9'])
a
# Out:
# ['哑而不干，持久不脱色。',
#  '色泽浓郁饱满，丝绒哑光妆效，8小时润泽舒适。',
#  '色彩浓郁，轻盈滋润，快速成膜，持久不脱色。',
#  '高饱和哑光色彩，至轻至薄，宛若无物，8小时不脱色。',
#  '唇蜜般水漾闪耀，润唇膏般柔润滋养，色彩饱满浓郁。',
#  '自然裸妆，细腻服帖。',
#  '控油持妆，高级雾面妆感。',
#  '奢润养肤，卓越遮瑕。',
#  '十年底妆传奇，细腻滋润不卡粉。',
#  '高遮瑕不假面，底妆整日在线。',
#  '自然细腻，裸感妆容。',
#  '轻薄贴肤，立体塑颜。',
#  '丝光无瑕，当红不让。',
#  '丝光无瑕，当红不让。',
#  '提亮肤色，持久保湿。',
#  '实力定妆，长效持妆。',
#  '细腻服帖，焕彩持妆。',
#  '细腻服帖，焕彩持妆。',
#  '清如薄纱，持久定妆。',
#  '高遮瑕，超持久，油皮挚爱之选。',
#  '隐形毛孔，控油持妆。',
#  '液体高光，点亮肌肤光彩。',
#  '液体修容，光影塑颜。',
#  '液体腮红，水漾自然。',
#  '粉质细腻，持久定妆。',
#  '精准遮瑕，隐匿细小瑕疵。',
#  '光泽色彩，精致双眸。',
#  '眸色风采。',
#  '流光溢彩，闪耀双眸。',
#  '持久防水，塑造卷曲睫毛。',
#  '丰盈饱满，持久定型不凝结。',
#  '丝滑持妆，打造大师魅力眼妆。',
#  '持久不晕染。',
#  '让人上瘾的眉笔，易于使用兼具防水。',
#  '轻松上妆，惊艳转变，颠覆传统。',
#  '防晒隔离，水润不黏腻。',
#  '轻盈至薄，多效防护。',
#  nan,
#  nan,
#  '阿玛尼秀场后台专用眼部卸妆液。',
#  '未上市。',
#  '镇牌面霜，看得见的修护力。',
#  '轻盈乳霜，看得见的修护力。',
#  '如面霜滋养，以光影修颜。',
#  '排浊面膜，去黄气排毒素。',
#  '抛光面膜，，净化肌肤，焕发光采。',
#  '火山面膜，深层清洁，深彻滋养。',
#  '深度滋润，塑造眼部马甲线。',
#  '全效眼霜，宛如眼部橡皮擦。',
#  '无皂基配方，敏感肌亦可使用。',
#  '智能型卸妆凝露，闭口黑头克星。',
#  '明星精华水，三维立体保湿。',
#  '液态珍珠流金质地，修护改善受损肌肤。',
#  '真皮层级的抗老化亮肤精华。',
#  '超渗透紧致精华，犹如隐形束身衣。',
#  nan,
#  '基础保养第一步，加强后续吸收。',
#  '未上市。',
#  nan,
#  '万能冻龄精油。',
#  '黑钥匙修护仪式，明星三宝体验装。',
#  nan,
#  nan,
#  nan,
#  '长效保湿，持久贴妆。',
#  '隐唇纹，固唇色，防外溢。',
#  nan,
#  '润泽保湿，持久定妆。',
#  '卸妆洁面，双效合一。',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '红色挚爱，全情以赴。',
#  '红色挚爱，全情以赴。',
#  '红色挚爱，星运限定。',
#  '红色香颂，挚爱限定。',
#  '挚爱女士，优雅自信。',
#  '挚爱女士，幻沙限定。',
#  '挚爱女士，优雅自信。',
#  '浓情挚爱，全情以赴。',
#  '温柔呵护，芳香四溢。',
#  '自由缱绻，畅游于海。',
#  '暖意盎然，甜美迷人。',
#  '渐次馥郁，花果清香。',
#  '纯净自然，畅快呼吸。',
#  '明媚花香，曼妙焕亮。',
#  '水生馥奇香调，强烈深海之息。',
#  '寄情典藏，馥郁经典。',
#  '纯澈如水，清新舒悦。',
#  '馥奇海洋香调，尽显沉稳活力。',
#  '纯澈如水，清新舒悦。',
#  '温和洁肤，纯净清爽。',
#  '高定香水，岩兰草。',
#  '高定香水，亚历山大玫瑰。',
#  '高定香水，牡丹凝香。',
#  '高定香水，无花果。',
#  '贵族私藏，限量幻沙牡丹。',
#  '高定私藏，冬日觉醒。',
#  '高定私藏，牡丹精灵。',
#  '高定私藏，东方茶韵。',
#  '高定私藏，永恒之光。',
#  '高定私藏，茉代芳华。',
#  '高定私藏，玫瑰品格。',
#  '高定私藏，伊甸仲夏。',
#  '高定私藏，日光天堂。',
#  '高定私藏，优雅之都。',
#  '高定香氛，私藏经典。',
#  '高定香氛，私藏经典。',
#  '高定香氛，私藏经典。',
#  '高定香氛，1001夜系列。',
#  '高定香氛，1001夜系列。',
#  '高定香氛，1001夜系列。',
#  '高定香氛，私藏经典。',
#  '高定香氛，1001夜系列。',
#  '高定香氛，环游系列，致敬俄罗斯。',
#  '高定香氛，环游系列，致敬俄罗斯。',
#  '高定香氛，环游系列，神秘印度。',
#  '高定香氛，环游系列，神秘印度。',
#  '高定香氛，1001夜系列。',
#  '高定香氛蜡烛。',
#  nan,
#  nan,
#  nan,
#  '红色挚爱，全情以赴。',
#  '挚爱女士，优雅自信。',
#  '纯澈如水，清新舒悦。',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '高级棕红，秋冬必选，时髦气质，出场即控场。',
#  nan,
#  '东方木质调，温郁内敛。']
